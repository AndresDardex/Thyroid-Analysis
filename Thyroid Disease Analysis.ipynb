# %%
import pandas as pd

# %%
data = pd.read_csv('thyroidDF.csv')

# %%
data.head()
# Out:
#    age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick pregnant  \
# 0   29   F            f                  f                   f    f        f
# 1   29   F            f                  f                   f    f        f
# 2   41   F            f                  f                   f    f        f
# 3   36   F            f                  f                   f    f        f
# 4   32   F            f                  f                   f    f        f
#
#   thyroid_surgery I131_treatment query_hypothyroid  ...    TT4 T4U_measured  \
# 0               f              f                 t  ...    NaN            f
# 1               f              f                 f  ...  128.0            f
# 2               f              f                 f  ...    NaN            f
# 3               f              f                 f  ...    NaN            f
# 4               f              f                 f  ...    NaN            f
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9172 entries, 0 to 9171
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  9172 non-null   int64
#  1   sex                  8865 non-null   object
#  2   on_thyroxine         9172 non-null   object
#  3   query_on_thyroxine   9172 non-null   object
#  4   on_antithyroid_meds  9172 non-null   object
#  5   sick                 9172 non-null   object
#  6   pregnant             9172 non-null   object
#  7   thyroid_surgery      9172 non-null   object
#  8   I131_treatment       9172 non-null   object
#  9   query_hypothyroid    9172 non-null   object
#  10  query_hyperthyroid   9172 non-null   object
#  11  lithium              9172 non-null   object
#  12  goitre               9172 non-null   object
#  13  tumor                9172 non-null   object
#  14  hypopituitary        9172 non-null   object
# ...

# %% [markdown]
# # Descripción de las columnas del dataset de pacientes con enfermedades tiroideas
#
# Este dataset contiene información clínica y de laboratorio sobre pacientes, enfocada en el diagnóstico y tratamiento de enfermedades tiroideas.
#
# | Columna              | Descripción                                                                                  |
# |----------------------|---------------------------------------------------------------------------------------------|
# | age                  | Edad del paciente (entero)                                                                  |
# | sex                  | Sexo con el que se identifica el paciente (cadena de texto)                                 |
# | on_thyroxine         | Si el paciente está tomando tiroxina (bool)                                                 |
# | query_on_thyroxine   | Si el paciente cree que está tomando tiroxina (bool)                                        |
# | on_antithyroid_meds  | Si el paciente está tomando medicamentos antitiroideos (bool)                               |
# | sick                 | Si el paciente está enfermo (bool)                                                          |
# | pregnant             | Si el paciente está embarazada (bool)                                                       |
# | thyroid_surgery      | Si el paciente ha sido sometido a cirugía tiroidea (bool)                                   |
# | I131_treatment       | Si el paciente está recibiendo tratamiento con I131 (bool)                                  |
# | query_hypothyroid    | Si el paciente cree que tiene hipotiroidismo (bool)                                         |
# | query_hyperthyroid   | Si el paciente cree que tiene hipertiroidismo (bool)                                        |
# | lithium              | Si el paciente toma litio (bool)                                                            |
# | goitre               | Si el paciente tiene bocio (bool)                                                           |
# | tumor                | Si el paciente tiene tumor (bool)                                                           |
# | hypopituitary        | Si el paciente tiene hipopituitarismo (bool/float)                                          |
# | psych                | Si el paciente tiene antecedentes psiquiátricos (bool)                                      |
# | TSH_measured         | Si se midió la TSH en sangre (bool)                                                         |
# | TSH                  | Nivel de TSH en sangre (float)                                                              |
# | T3_measured          | Si se midió la T3 en sangre (bool)                                                          |
# | T3                   | Nivel de T3 en sangre (float)                                                               |
# | TT4_measured         | Si se midió la TT4 en sangre (bool)                                                         |
# | TT4                  | Nivel de TT4 en sangre (float)                                                              |
# | T4U_measured         | Si se midió la T4U en sangre (bool)                                                         |
# | T4U                  | Nivel de T4U en sangre (float)                                                              |
# | FTI_measured         | Si se midió el FTI en sangre (bool)                                                         |
# | FTI                  | Nivel de FTI en sangre (float)                                                              |
# | TBG_measured         | Si se midió la TBG en sangre (bool)                                                         |
# | TBG                  | Nivel de TBG en sangre (float)                                                              |
# | referral_source      | Fuente de referencia del paciente (cadena de texto)                                         |
# | target               | Diagnóstico médico de hipertiroidismo (cadena de texto)                                     |
# | patient_id           | Identificador único del paciente (cadena de texto)                                          |

# %%
len(data)
# Out:
# 9172

# %%
nulos = data.isnull().sum()
nulos[nulos != 0]
# Out:
# sex     307
# TSH     842
# T3     2604
# TT4     442
# T4U     809
# FTI     802
# TBG    8823
# dtype: int64

# %%
nulos = nulos / len(data) * 100
nulos = nulos.sort_values(ascending=False)
nulos.head(10)
# Out:
# TBG             96.194941
# T3              28.390754
# TSH              9.180113
# T4U              8.820323
# FTI              8.744003
# TT4              4.819014
# sex              3.347143
# age              0.000000
# TSH_measured     0.000000
# target           0.000000
# dtype: float64

# %%
data['TBG_measured'].value_counts()
# Out:
# f    8823
# t     349
# Name: TBG_measured, dtype: int64

# %%
data['T3_measured'].value_counts()
# Out:
# t    6568
# f    2604
# Name: T3_measured, dtype: int64

# %%
data['FTI_measured'].value_counts()
# Out:
# t    8370
# f     802
# Name: FTI_measured, dtype: int64

# %%
data['sex'] = data['sex'].fillna(data['sex'].mode()[0])

# %%
data.describe()
# Out:
#                 age          TSH           T3          TT4          T4U  \
# count   9172.000000  8330.000000  6568.000000  8730.000000  8363.000000
# mean      73.555822     5.218403     1.970629   108.700305     0.976056
# std     1183.976718    24.184006     0.887579    37.522670     0.200360
# min        1.000000     0.005000     0.050000     2.000000     0.170000
# 25%       37.000000     0.460000     1.500000    87.000000     0.860000
# 50%       55.000000     1.400000     1.900000   104.000000     0.960000
# 75%       68.000000     2.700000     2.300000   126.000000     1.065000
# max    65526.000000   530.000000    18.000000   600.000000     2.330000
#
#                FTI         TBG    patient_id
# count  8370.000000  349.000000  9.172000e+03
# mean    113.640746   29.870057  8.529473e+08
# std      41.551650   21.080504  7.581969e+06
# min       1.400000    0.100000  8.408010e+08
# 25%      93.000000   21.000000  8.504090e+08
# 50%     109.000000   26.000000  8.510040e+08
# ...

# %%
#histograma de edad
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 5))
sns.histplot(data['age'], bins=30, kde=True)
plt.title('Distribución de Edad')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
#ordenar edad de mayor a menor para ver outliers
data.age.max(), data.age.min()
# Out:
# (65526, 1)

# %%
data[data['age'] > 100]
# Out:
#         age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 2976    455   F            f                  f                   f    f
# 5710  65511   M            f                  f                   f    f
# 6392  65512   M            f                  f                   f    f
# 8105  65526   F            f                  f                   f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...    TT4  \
# 2976        f               f              f                 f  ...  118.0
# 5710        f               f              f                 f  ...  113.0
# 6392        f               f              f                 f  ...  112.0
# 8105        f               f              f                 f  ...  132.0
#
#      T4U_measured   T4U FTI_measured    FTI TBG_measured TBG  referral_source  \
# 2976            t  1.13            t  104.0            f NaN              SVI
# ...

# %%
#eliminar outliers de edad
data = data[(data['age'] < 100)]
#histograma de edad
plt.figure(figsize=(10, 5))
sns.histplot(data['age'], bins=30, kde=True)
plt.title('Distribución de Edad')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['TSH'], bins=30, kde=True)
plt.title('Distribución de TSH')
plt.xlabel('TSH')
plt.ylabel('Frecuencia')
plt.show()

# %%
#cuartil 95 de TSH
data = data[(data['TSH'] < data['TSH'].quantile(0.95)) | (data['TSH'].isnull())]

plt.figure(figsize=(10, 5))
sns.histplot(data['TSH'], bins=30, kde=True)
plt.title('Distribución de TSH')
plt.xlabel('TSH')
plt.ylabel('Frecuencia')
plt.show()

# %%
#cuartil 95 de T3
data = data[(data['T3'] < data['T3'].quantile(0.95)) | (data['T3'].isnull())]

plt.figure(figsize=(10, 5))
sns.histplot(data['T3'], bins=30, kde=True)
plt.title('Distribución de T3')
plt.xlabel('T3')
plt.ylabel('Frecuencia')
plt.show()

# %%
#cuartil 95 de TSH
data = data[(data['TT4'] < data['TT4'].quantile(0.99)) | (data['TT4'].isnull())]

plt.figure(figsize=(10, 5))
sns.histplot(data['TT4'], bins=30, kde=True)
plt.title('Distribución de TT4')
plt.xlabel('TT4')
plt.ylabel('Frecuencia')
plt.show()

# %%
#cuartil 95 de TSH
#data = data[data['TT4'] < data['TT4'].quantile(0.99)]

plt.figure(figsize=(10, 5))
sns.histplot(data['T4U'], bins=30, kde=True)
plt.title('Distribución de T4U')
plt.xlabel('T4U')
plt.ylabel('Frecuencia')
plt.show()

# %%
#cuartil 95 de TSH
data = data[(data['FTI'] < data['FTI'].quantile(0.99)) | (data['FTI'].isnull())]

plt.figure(figsize=(10, 5))
sns.histplot(data['FTI'], bins=30, kde=True)
plt.title('Distribución de FTI')
plt.xlabel('FTI')
plt.ylabel('Frecuencia')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8265 entries, 0 to 9171
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  8265 non-null   int64
#  1   sex                  8265 non-null   object
#  2   on_thyroxine         8265 non-null   object
#  3   query_on_thyroxine   8265 non-null   object
#  4   on_antithyroid_meds  8265 non-null   object
#  5   sick                 8265 non-null   object
#  6   pregnant             8265 non-null   object
#  7   thyroid_surgery      8265 non-null   object
#  8   I131_treatment       8265 non-null   object
#  9   query_hypothyroid    8265 non-null   object
#  10  query_hyperthyroid   8265 non-null   object
#  11  lithium              8265 non-null   object
#  12  goitre               8265 non-null   object
#  13  tumor                8265 non-null   object
#  14  hypopituitary        8265 non-null   object
# ...

# %%
data.to_csv('thyroid_cleaned.csv', index=False)
